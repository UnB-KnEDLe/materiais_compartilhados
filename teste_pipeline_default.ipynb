# %%
# %pip install dodfminer=="1.3.18rc3"

# %%
from dodfminer.extract.polished.core import ActsExtractor

res1 = ActsExtractor.get_all_obj("./jsons/DODF 151 11-08-2022.json")
# Out:
# Foram encontrados 7 atos de contrato/convênio
# Foram encontrados 5 atos de aditamento
# Foram encontrados 13 atos de licitação
# Foram encontrados 1 atos de suspensão
# Foram encontrados 0 atos de anulação/revogação

# %%
res1['aditamento'].df
# Out:
#   numero_dodf                                             titulo  \
# 0         151  EXTRATO DO 16º TERMO ADITIVO AO CONTRATO CCER ...
# 1         151  EXTRATO DO 16º TERMO ADITIVO AO CONTRATO CUSD ...
# 2         151  EXTRATO DO 9° TERMO ADITIVO AO CONTRATO Nº 06/...
# 3         151  EXTRATO DO TERCEIRO TERMO ADITIVO DE PRORROGAÇ...
# 4         151  EXTRATO DO PRIMEIRO TERMO ADITIVO AO CONTRATO ...
#
#                                                 text             NUM_ADITIVO  \
# 0  EXTRATO DO 16º TERMO ADITIVO AO CONTRATO CCER ...       16º TERMO ADITIVO
# 1  EXTRATO DO 16º TERMO ADITIVO AO CONTRATO CUSD ...       16º TERMO ADITIVO
# 2  EXTRATO DO 9° TERMO ADITIVO AO CONTRATO Nº 06/...        9° TERMO ADITIVO
# 3  EXTRATO DO TERCEIRO TERMO ADITIVO DE PRORROGAÇ...  TERCEIRO TERMO ADITIVO
# 4  EXTRATO DO PRIMEIRO TERMO ADITIVO AO CONTRATO ...  PRIMEIRO TERMO ADITIVO
#
#                                           NUM_AJUSTE  \
# 0                                          0714/2017
# ...

# %%
res2 = ActsExtractor.get_act_obj("contrato_convenio", "./jsons/DODF 151 11-08-2022.json")
# Out:
# Foram encontrados 7 atos de contrato/convênio

# %%
res2.df
# Out:
#   numero_dodf                                             titulo  \
# 0         151       EXTRATO DO CONTRATO Nº 047103/2022 - SEEC/DF
# 1         151             EXTRATO DO CONTRATO Nº 47067/2022-SEEC
# 2         151                     EXTRATO DO CONTRATO Nº 05/2022
# 3         151                                EXTRATO DE CONTRATO
# 4         151    EXTRATO DO CONTRATO Nº 025/2022 – DCC/UNIAF/FHB
# 5         151  EXTRATO DO CONTRATO DE PRESTAÇÃO DOS SERVIÇOS ...
# 6         151  EXTRATO DO CONTRATO DE CONCESSÃO DE DIREITO RE...
#
#                                                 text  \
# 0  EXTRATO DO CONTRATO Nº 047103/2022 - SEEC/DF P...
# 1  EXTRATO DO CONTRATO Nº 47067/2022-SEEC Process...
# 2  EXTRATO DO CONTRATO Nº 05/2022 Processo nº 040...
# 3  EXTRATO DE CONTRATO A CARTÃO BRB S.A. torna pú...
# 4  EXTRATO DO CONTRATO Nº 025/2022 – DCC/UNIAF/FH...
# 5  EXTRATO DO CONTRATO DE PRESTAÇÃO DOS SERVIÇOS ...
# 6  EXTRATO DO CONTRATO DE CONCESSÃO DE DIREITO RE...
#
# ...
